# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\rohit\Downloads\car data.csv')
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
print(df['Seller_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
final_dataset=df[['Year','Selling_Price','Present_Price','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner']]

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
final_dataset['Current_year']=2020

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_year
# 0       Manual      0          2020
# 1       Manual      0          2020
# 2       Manual      0          2020
# 3       Manual      0          2020
# 4       Manual      0          2020

# %%
final_dataset['no of year']=final_dataset['Current_year']-final_dataset['Year']

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_year  no of year
# 0       Manual      0          2020           6
# 1       Manual      0          2020           7
# 2       Manual      0          2020           3
# 3       Manual      0          2020           9
# 4       Manual      0          2020           6

# %%
final_dataset.drop(['Year'],axis=1,inplace=True)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_year  no of year
# 0       Manual      0          2020           6
# 1       Manual      0          2020           7
# 2       Manual      0          2020           3
# 3       Manual      0          2020           9
# 4       Manual      0          2020           6

# %%
final_dataset.drop(['Current_year'],axis=1,inplace=True)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  no of year
# 0       Manual      0           6
# 1       Manual      0           7
# 2       Manual      0           3
# 3       Manual      0           9
# 4       Manual      0           6

# %%
final_dataset=pd.get_dummies(final_dataset,drop_first=True)
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  no of year  \
# 0             3.35           5.59       27000      0           6
# 1             4.75           9.54       43000      0           7
# 2             7.25           9.85        6900      0           3
# 3             2.85           4.15        5200      0           9
# 4             4.60           6.87       42450      0           6
# ..             ...            ...         ...    ...         ...
# 296           9.50          11.60       33988      0           4
# 297           4.00           5.90       60000      0           5
# 298           3.35          11.00       87934      0          11
# 299          11.50          12.50        9000      0           3
# 300           5.30           5.90        5464      0           4
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                   0                 1                       0
# 1                   1                 0                       0
# 2                   0                 1                       0
# 3                   0                 1                       0
# 4                   1                 0                       0
# ..                ...               ...                     ...
# 296                 1                 0                       0
# 297                 0                 1                       0
# 298                 0                 1                       0
# 299                 1                 0                       0
# 300                 0                 1                       0
#
#      Transmission_Manual
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ..                   ...
# 296                    1
# 297                    1
# 298                    1
# 299                    1
# 300                    1
#
# [301 rows x 9 columns]

# %%
final_dataset.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# no of year                  -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                         no of year  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price            -0.236141          0.552339         -0.540571
# Present_Price             0.047584          0.473306         -0.465244
# Kms_Driven                0.524342          0.172515         -0.172874
# Owner                     0.182104         -0.053469          0.055687
# no of year                1.000000         -0.064315          0.059959
# Fuel_Type_Diesel         -0.064315          1.000000         -0.979648
# Fuel_Type_Petrol          0.059959         -0.979648          1.000000
# Seller_Type_Individual    0.039896         -0.350467          0.358321
# Transmission_Manual      -0.000394         -0.098643          0.091013
#
#                         Seller_Type_Individual  Transmission_Manual
# Selling_Price                        -0.550724            -0.367128
# Present_Price                        -0.512030            -0.348715
# Kms_Driven                           -0.101419            -0.162510
# Owner                                 0.124269            -0.050316
# no of year                            0.039896            -0.000394
# Fuel_Type_Diesel                     -0.350467            -0.098643
# Fuel_Type_Petrol                      0.358321             0.091013
# Seller_Type_Individual                1.000000             0.063240
# Transmission_Manual                   0.063240             1.000000

# %%
sns.pairplot(final_dataset)

# %%
corrmat=final_dataset.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(final_dataset[top_corr_features].corr(),annot=True,cmap='RdYlGn')

# %%
x=final_dataset.iloc[:,1:]
y=final_dataset.iloc[:,0]

# %%
x.head()
# Out:
#    Present_Price  Kms_Driven  Owner  no of year  Fuel_Type_Diesel  \
# 0           5.59       27000      0           6                 0
# 1           9.54       43000      0           7                 1
# 2           9.85        6900      0           3                 0
# 3           4.15        5200      0           9                 0
# 4           6.87       42450      0           6                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.36061533 0.0399824  0.00040089 0.07942318 0.2453347  0.00960811
#  0.12349111 0.14114429]

# %%
f=pd.Series(model.feature_importances_,index=x.columns)
f.nlargest(5).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
print('shape of x train:' ,xtrain.shape)
print('shape of x test:' ,xtest.shape)
print('shape of y train:' ,ytrain.shape)
print('shape of y test:' ,ytest.shape)
# Out:
# shape of x train: (240, 8)
# shape of x test: (61, 8)
# shape of y train: (240,)
# shape of y test: (61,)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model=RandomForestRegressor()
rf_model
# Out:
# RandomForestRegressor()

# %%
n_estimators=[int(x) for x in np.linspace(start=100,stop=1200,num=12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
max_features=['auto','sqrt']
max_depth=[int(x) for x in np.linspace(5,30,num=6)]
min_samples_split=[2,5,10,20,25,100]
min_samples_leaf=[1,2,5,10]

# %%
from sklearn.model_selection import RandomizedSearchCV
r_grid={'n_estimators':n_estimators,'max_features':max_features,'max_depth':max_depth,\
        'min_samples_split':min_samples_split,'min_samples_leaf':min_samples_leaf}

# %%
rf=RandomForestRegressor()
rf_random=RandomizedSearchCV(estimator=rf,param_distributions=r_grid,n_iter=10,\
                             random_state=10,verbose=2,scoring='neg_mean_squared_error',cv=5)

# %%
rf_random.fit(xtrain,ytrain)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=15
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=15, total=   1.3s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=15
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=15, total=   1.4s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=15
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=15, total=   1.4s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=15
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=15, total=   1.2s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=15
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=15, total=   1.3s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   1.3s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   1.3s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   1.3s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   1.3s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   1.1s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   2.5s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   2.4s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   2.3s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   2.4s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   2.5s
# [CV] n_estimators=100, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=100, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15, total=   0.2s
# [CV] n_estimators=100, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=100, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15, total=   0.2s
# [CV] n_estimators=100, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=100, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15, total=   0.2s
# [CV] n_estimators=100, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=100, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15, total=   0.2s
# [CV] n_estimators=100, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=100, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15, total=   0.2s
# [CV] n_estimators=1000, min_samples_split=25, min_samples_leaf=10, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1000, min_samples_split=25, min_samples_leaf=10, max_features=sqrt, max_depth=30, total=   2.1s
# [CV] n_estimators=1000, min_samples_split=25, min_samples_leaf=10, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1000, min_samples_split=25, min_samples_leaf=10, max_features=sqrt, max_depth=30, total=   2.1s
# [CV] n_estimators=1000, min_samples_split=25, min_samples_leaf=10, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1000, min_samples_split=25, min_samples_leaf=10, max_features=sqrt, max_depth=30, total=   2.0s
# [CV] n_estimators=1000, min_samples_split=25, min_samples_leaf=10, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1000, min_samples_split=25, min_samples_leaf=10, max_features=sqrt, max_depth=30, total=   2.0s
# [CV] n_estimators=1000, min_samples_split=25, min_samples_leaf=10, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1000, min_samples_split=25, min_samples_leaf=10, max_features=sqrt, max_depth=30, total=   2.1s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   0.9s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   0.8s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   0.9s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   0.8s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   0.9s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=15, total=   1.2s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=15, total=   1.1s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=15, total=   1.1s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=15, total=   1.2s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=15, total=   1.1s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=20, total=   1.2s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=20, total=   1.4s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=20, total=   1.2s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=20, total=   1.2s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=20, total=   1.3s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=10, total=   0.4s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=10, total=   0.5s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=10, total=   0.5s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=10, total=   0.5s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=10, total=   0.4s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   1.9s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   1.8s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   1.9s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   1.9s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   1.9s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  1.1min finished
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(),
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 20, 25,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    random_state=10, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
predictedvalues=rf_random.predict(xtest)

# %%
predictedvalues
# Out:
# array([22.71400912,  4.93782878,  2.69345071, 22.69890466,  0.4289246 ,
#         8.03114119, 21.91350201,  6.76792496,  3.85835854,  3.34023151,
#         0.26732643,  5.78111721,  3.43346569, 10.12215515,  0.21550457,
#         3.2257386 ,  3.02480323,  9.64568356,  4.313263  ,  1.43911542,
#         9.09047018,  7.13909505,  1.14587652,  5.29646939, 13.14626093,
#         7.49358407,  6.83717882,  4.63494729,  7.02598025,  0.70548452,
#         0.48256928,  3.49448689,  3.14627155,  2.94214883,  6.3974565 ,
#         5.10608233,  0.43344535,  0.70745176,  5.47237823,  6.37355248,
#         1.83303805,  7.73229844,  7.95117482,  2.88200117,  1.20875986,
#         0.63181555,  0.57325177,  3.92425711,  0.2292826 ,  9.89919979,
#         0.83327914,  2.73394134,  0.43123087,  0.43902728,  4.26439039,
#         4.68497398, 10.19683554,  2.77711342,  5.21086386, 14.53592966,
#         1.03874755])

# %%
sns.distplot(ytest-predictedvalues)
# Out:
# E:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Selling_Price', ylabel='Density'>

# %%
plt.scatter(ytest,predictedvalues)

# %%
import pickle
path="C:/Users/rohit/Downloads/car_dekho_project/"
file=open(path+'random_forest_regressor_model.pkl','wb')
pickle.dump(rf_random,file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-99-2b8794867dc6> in <module>
#       1 import pickle
#       2 path="C:/Users/rohit/Downloads/car_dekho_project/"
# ----> 3 file=open(path+'random_forest_regressor_model.pkl','wb')
#       4 pickle.dump(rf_random,file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/rohit/Downloads/car_dekho_project/random_forest_regressor_model.pkl'
